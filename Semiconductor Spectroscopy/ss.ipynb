# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# %%
def readd(name, skip, maxrows):
    return np.loadtxt(f'Daten/{name}', delimiter = '\t', skiprows = skip, max_rows = maxrows)
def plott(data):
    plt.plot(data[:,0], data[:,1])

# %%
#Exercise 0

# %%
led_data = np.loadtxt('Daten/Led.Master.Scope', delimiter = '\t', skiprows = 24, max_rows = 2040)

# %%
Leuchtstoff_Lampe_data = np.loadtxt('Daten/Leuchtstoff_Lampe.Master.Scope', delimiter = '\t', skiprows = 24, max_rows = 2040)

# %%
lamp_data = np.loadtxt('Daten/Lampe_1.Master.Scope', delimiter = '\t', skiprows = 24, max_rows = 2040)

# %%
plt.plot(Leuchtstoff_Lampe_data[:, 0], Leuchtstoff_Lampe_data[:, 1], label = 'Light tube spectrum',
        color = 'green')
plt.plot(led_data[:, 0], led_data[:, 1], label = 'LED spectrum',
        color = 'blue')
plt.plot(lamp_data[:, 0], lamp_data[:, 1], label = 'Glowing light bulb spectrum',
        color = 'red')
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I$')
plt.legend()
plt.savefig('ss_ex0.jpg', dpi = 800)

# %%
plt.plot(led_data[:, 0], led_data[:, 1], label = 'LED spectrum',
        color = 'blue')
plt.grid()
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I$')
plt.legend()

# %%
plt.plot(lamp_data[:, 0], lamp_data[:, 1], label = 'Glowing light bulb spectrum',
        color = 'blue')
plt.grid()
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I$')
plt.legend()

# %%
#Exercise 1

# %%
start = 150
stop = 1900
plt.plot(readd('Aufg1_GlasStab_WG.Master.Transmission', start, stop)[:,0], 
        readd('Aufg1_GlasStab_WG.Master.Transmission', start, stop)[:,1],
        label = 'yellow',
        color = 'yellow'
        )
plt.axvline(x = 460, color = 'black', linestyle = '--')
plt.plot(readd('Aufg1_GlasStab_G.Master.Transmission', start, stop)[:,0], 
        readd('Aufg1_GlasStab_G.Master.Transmission', start, stop)[:,1],
        label = 'light orange',
         color = 'gold'
        )
plt.axvline(x = 510, color = 'black', linestyle = '--')
plt.plot(readd('Aufg1_GlasStab_RO.Master.Transmission', start, stop)[:,0], 
        readd('Aufg1_GlasStab_RO.Master.Transmission', start, stop)[:,1],
        label = 'dark orange',
         color = 'orange'
        )
plt.axvline(x = 595, color = 'black', linestyle = '--')
plt.plot(readd('Aufg1_GlasStab_RS.Master.Transmission', start, stop)[:,0], 
        readd('Aufg1_GlasStab_RS.Master.Transmission', start, stop)[:,1],
        label = 'transparent red',
        color = 'red'
        )
plt.axvline(x = 613, color = 'black', linestyle = '--')
plt.plot(readd('Aufg1_GlasStab_S.Master.Transmission', start, stop)[:,0], 
        readd('Aufg1_GlasStab_S.Master.Transmission', start, stop)[:,1],
        label = 'opaque red',
        color = 'maroon'
        )
plt.axvline(x = 616, color = 'black', linestyle = '--')

plt.grid()
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I_\mathrm{{trans}}$')
plt.legend()
plt.savefig('ss_ex1.jpg', dpi = 800)

# %%
#Exercise 2

# %%
#plott(readd('Aufg2_CDSPolar_Grund.Master.Transmission', 150, 1900))
#plott(readd('Aufg2_CDSPolar_Red.Master.Transmission', 150, 1900))
#plott(readd('Aufg2_CDSPolar_Blue.Master.Transmission', 150, 1900))

start = 150
stop = 1900
plt.plot(readd('Aufg2_CDSPolar_Grund.Master.Transmission', start, stop)[:,0], 
        readd('Aufg2_CDSPolar_Grund.Master.Transmission', start, stop)[:,1],
        label = 'Grund'
        )
plt.plot(readd('Aufg2_CDSPolar_Red.Master.Transmission', start, stop)[:,0], 
        readd('Aufg2_CDSPolar_Red.Master.Transmission', start, stop)[:,1],
        label = 'Red'
        )
plt.plot(readd('Aufg2_CDSPolar_Blue.Master.Transmission', start, stop)[:,0], 
        readd('Aufg2_CDSPolar_Blue.Master.Transmission', start, stop)[:,1],
        label = 'Blue'
        )
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I_\mathrm{{trans}}$')
plt.legend()

# %%
#plott(readd('Aufg2_CDSPolar_Grund.Master.Transmission', 400, 500))
#plott(readd('Aufg2_CDSPolar_Red.Master.Transmission', 400, 500))
#plott(readd('Aufg2_CDSPolar_Blue.Master.Transmission', 400, 500))

start = 520
stop = 360
'''
plt.plot(readd('Aufg2_CDSPolar_Grund.Master.Transmission', start, stop)[:,0], 
         readd('Aufg2_CDSPolar_Grund.Master.Transmission', start, stop)[:,1],
         label = 'Base',
         color = 'green'
        )
'''
plt.plot(readd('Aufg2_CDSPolar_Red.Master.Transmission', start, stop)[:,0], 
        readd('Aufg2_CDSPolar_Red.Master.Transmission', start, stop)[:,1],
        label = 'minimum transmission',
         color = 'red',
        )
plt.axvline(x = 511, color = 'black', linestyle = '--')

plt.axvline(x = 519, color = 'maroon', linestyle = '--')
plt.axvline(x = 529, color = 'maroon', linestyle = '--')
plt.axvline(x = 541, color = 'maroon', linestyle = '--')
plt.axvline(x = 557, color = 'maroon', linestyle = '--')
peaks_red = np.array([511, 519, 529, 541, 557])

plt.plot(readd('Aufg2_CDSPolar_Blue.Master.Transmission', start, stop)[:,0], 
        readd('Aufg2_CDSPolar_Blue.Master.Transmission', start, stop)[:,1],
        label = 'maximum transmission',
         color = 'blue'
        )
plt.axvline(x = 508, color = 'black', linestyle = '--', label = 'absorption edges')

plt.axvline(x = 557, color = 'maroon', linestyle = '--', label = 'minimum transmission peaks')

plt.axvline(x = 518, color = 'navy', linestyle = '--')
plt.axvline(x = 528.5, color = 'navy', linestyle = '--')
plt.axvline(x = 542, color = 'navy', linestyle = '--')
plt.axvline(x = 559, color = 'navy', linestyle = '--', label = 'maximum transmission peaks')
peaks_blue = np.array([508, 518, 528.5, 542, 559])

    
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I_\mathrm{{trans}}$')
plt.legend()
plt.savefig('ss_ex2_spectra.jpg', dpi = 800)

# %%
def n(lam):
    return 1.94 * (1 + 4696/(2*sp.constants.pi*sp.constants.c)/(1/(390)**2 - 1/(lam)**2))


def line(x,a,b):
    return 4*a*x + b

plt.scatter(n(peaks_red)/peaks_red, np.arange(0, 5, 1), color = 'red',
           label = 'minimum transmission peaks')
popt_red, pcov_red = sp.optimize.curve_fit(line, n(peaks_red)/peaks_red, np.arange(0, 5, 1))
plt.plot(n(peaks_red)/peaks_red, line(n(peaks_red)/peaks_red, *popt_red),
         color = 'maroon', linestyle = '--', 
         label = fr'fit: $d = {np.round(-popt_red[0], 2)} \pm {np.round(pcov_red[0][0]**0.5, 2)}$ nm')
plt.scatter(n(peaks_blue)/peaks_blue, np.arange(0, 5, 1), color = 'blue', 
            label = 'maximum transmission peaks')
popt_blue, pcov_blue = sp.optimize.curve_fit(line, n(peaks_blue)/peaks_blue, np.arange(0, 5, 1))
plt.plot(n(peaks_blue)/peaks_blue, line(n(peaks_blue)/peaks_blue, *popt_blue), 
         color = 'navy', linestyle = '--', 
        label = fr'fit: $d = {np.round(-popt_blue[0], 2)} \pm {np.round(pcov_blue[0][0]**0.5, 2)}$ nm')

plt.xlabel(fr'$\frac{{4n(\lambda)}}{{n}}$')
plt.ylabel('peak order')
plt.legend()
plt.savefig('ss_ex2_linear_fits.jpg', dpi = 800)

# %%
#Exercise 3

# %%
#plott(readd('Aufg3_QuantWell_RaumTemp.Master.Transmission', 350, 1717))
start = 800
stop = 1267
plt.plot(readd('Aufg3_QuantWell_RaumTemp.Master.Transmission', start, stop)[:,0], 
        readd('Aufg3_QuantWell_RaumTemp.Master.Transmission', start, stop)[:,1],
        label = 'transmission at 300K',
         color = 'red'
        )
plt.plot(readd('Aufg3_QuantWell_Kalt.Master.Transmission', start, stop)[:,0], 
        readd('Aufg3_QuantWell_Kalt.Master.Transmission', start, stop)[:,1],
        label = 'transmission at 77K',
         color = 'blue'
        )
plt.axvline(x = 773, color = 'navy', linestyle = '--', 
            label = fr'absorption peak ($\lambda = 773$ nm)')
plt.axvline(x = 785, color = 'navy', linestyle = '--',
            label = fr'absorption peak ($\lambda = 785$ nm)')

plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I_\mathrm{{trans}}$')
plt.legend()
plt.savefig('ss_ex3.jpg', dpi = 800)

# %%
#Aufgabe 4

# %%
start = 850
stop = 400
plt.plot(readd('Aufg4_Dick_Kalt.Master.Absorbance', start, stop)[:,0], 
        readd('Aufg4_Dick_Kalt.Master.Absorbance', start, stop)[:,1],
        label = 'absorbance at 77K',
         color = 'blue'
        )
plt.axvline(x = 578, color = 'green', linestyle = '--', 
            label = fr'3p ($\lambda = 578$ nm)')
plt.axvline(x = 583, color = 'red', linestyle = '--', 
            label = fr'2p ($\lambda = 583$ nm)')
plt.axvline(x = 613, color = 'black', linestyle = '--', 
            label = fr'1s ($\lambda = 613 - 622$ nm)')
plt.axvline(x = 622, color = 'black', linestyle = '--')

plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I$')
plt.grid()
plt.legend()
plt.savefig('ss_ex4_thick_cold.jpg', dpi = 800)

# %%
start = 850
stop = 300
plt.plot(readd('Aufg4_Duenn_Kalt.Master.Absorbance', start, stop)[:,0], 
        readd('Aufg4_Duenn_Kalt.Master.Absorbance', start, stop)[:,1],
        label = 'absorbance at 77K'
        )
plt.axvline(x = 578, color = 'green', linestyle = '--', 
            label = fr'3p ($\lambda = 578$ nm)')
plt.axvline(x = 582, color = 'red', linestyle = '--', 
            label = fr'2p ($\lambda = 582$ nm)')
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I$')
plt.grid()
plt.legend()
plt.savefig('ss_ex4_thin_cold.jpg', dpi = 800)

# %%
start = 400
stop = 1667
plt.plot(readd('Aufg4_Dick_RT.Master.Transmission', start, stop)[:,0], 
        readd('Aufg4_Dick_RT.Master.Transmission', start, stop)[:,1],
        label = '300K'
        )
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I_\mathrm{{trans}}$')
plt.legend()

# %%
start = 400
stop = 1667
plt.plot(readd('Aufg4_Duenn_RT.Master.Transmission', start, stop)[:,0], 
        readd('Aufg4_Duenn_RT.Master.Transmission', start, stop)[:,1],
        label = '300K'
        )
plt.xlabel(fr'$\lambda$ [nm]')
plt.ylabel(fr'$I_\mathrm{{trans}}$')
plt.legend()
